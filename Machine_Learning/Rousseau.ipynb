# %% [markdown]
# # Projet Voltaire 2.0 : Rousseau
# ### Equipe 242
#
#
# **Etape 1** : import des librairies

# %%
import pandas as pd
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten,Dropout,Conv2D
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding

# %% [markdown]
# **Etape 2** : conversion des datasets (.csv) en dataframes pandas et retrait des valeurs aberrantes

# %%
df = pd.read_csv('../Dataset/Data/moyenne.csv')
df = df.dropna()
df
# Out:
#                                                  answer  is_true
# 0     HBOHBSTLHBPQHBMHBGDMaOBGDMBEBMBCCPBCGBSBTMeOBCBPM        0
# 1     HBOHBSTLHBPQHBMHBGDMaOBGDMBEBMBCCPBCGBSBTMeOBC...        0
# 2     HBOHBSTLHBPQHBMHBGDMaOBGDMBEBMBCCPBCGBSBTMeOBC...        1
# 3      HBOHBSTLHBPQHBGDMaOHBGDMBEBMBCCPQBGBCBSBTMReBCBR        0
# 4     HBOHBSTLHBPQHBGDMaOHBGDMBEBMBCCPQBGBCBSBTMReBCBMR        1
# ...                                                 ...      ...
# 2034  HBOHNBLHBPQHBMHBMaOBGDMBEBMBCCPQBCGNOBCBPMReBCBMR        1
# 2035  HBOHNBLHBPQHBGDMHBMaOBGDMBEBMBCCPQBCGNOBCBPMRe...        1
# 2036  HBOHNBLHBPQHBGDLBGDMaOHBGDMBEBMBCCPQBCGNOBCBPM...        1
# 2037  HBOHNBLHBPQHBGDLBGDMaOHBGDMBEBMBCCPQBCGNOBCBPM...        1
# 2038  HBOHNBLHBPQHBGDLBGDMaOHBGDMBEBMBCCPQBCGNOBCBPM...        1
#
# [1842 rows x 2 columns]

# %% [markdown]
# **Etape 3** : Tokeniser les lexemes, et vectorisation des reponses

# %%
tok = Tokenizer(char_level=True)
tok.fit_on_texts(df.answer)
ma = max([len(i) for i in df["answer"]])
ma
X = tok.texts_to_sequences(df["answer"])
X = sequence.pad_sequences(X, maxlen=ma)
print(ma)
# Out:
# 265

# %% [markdown]
# **Etape 4** : Creation modele

# %%
model = Sequential()
model.add(Embedding(len(tok.word_index)+1, 8, input_length=ma))
model.add(Conv1D(filters=16, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 265, 8)            176
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 265, 16)           272
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 265, 16)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 4240)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                135712
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 136,193
# Trainable params: 136,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Etape 5 : Entrainement Modele

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df["is_true"], test_size=0.4)
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=15, batch_size=1)
# Out:
# Epoch 1/15
# 1105/1105 [==============================] - 6s 4ms/step - loss: 0.6047 - accuracy: 0.6697 - val_loss: 0.5262 - val_accuracy: 0.7490
# Epoch 2/15
#  - ETA: 2s - loss: 0.5397 - accuracy: 0.7442
# Epoch 3/15
# 1105/1105 [==============================] - 3s 3ms/step - loss: 0.4350 - accuracy: 0.8036 - val_loss: 0.4693 - val_accuracy: 0.7910
# Epoch 4/15
# 1105/1105 [==============================] - 3s 3ms/step - loss: 0.3971 - accuracy: 0.8172 - val_loss: 0.4788 - val_accuracy: 0.7965
# Epoch 5/15
#  - ETA: 1s - loss: 0.3432 - accuracy: 0.8491
# Epoch 6/15
# 1105/1105 [==============================] - 4s 4ms/step - loss: 0.3423 - accuracy: 0.8579 - val_loss: 0.4856 - val_accuracy: 0.8046
# Epoch 7/15
# 1105/1105 [==============================] - 5s 5ms/step - loss: 0.3261 - accuracy: 0.8760 - val_loss: 0.4500 - val_accuracy: 0.8046
# Epoch 8/15
#  - ETA: 2s - loss: 0.3397 - accuracy: 0.8632
# Epoch 9/15
# 1105/1105 [==============================] - 6s 5ms/step - loss: 0.2907 - accuracy: 0.8842 - val_loss: 0.4644 - val_accuracy: 0.8182
# Epoch 10/15
# 1105/1105 [==============================] - 6s 6ms/step - loss: 0.2658 - accuracy: 0.8968 - val_loss: 0.5146 - val_accuracy: 0.8263
# Epoch 11/15
# 1105/1105 [==============================] - 6s 6ms/step - loss: 0.2765 - accuracy: 0.8950 - val_loss: 0.5015 - val_accuracy: 0.8195
# Epoch 12/15
# 1105/1105 [==============================] - 4s 3ms/step - loss: 0.2474 - accuracy: 0.9050 - val_loss: 0.5186 - val_accuracy: 0.8358
# Epoch 13/15
# 1105/1105 [==============================] - 4s 3ms/step - loss: 0.2428 - accuracy: 0.9041 - val_loss: 0.5341 - val_accuracy: 0.8250
# Epoch 14/15
# 1105/1105 [==============================] - 4s 4ms/step - loss: 0.2224 - accuracy: 0.9122 - val_loss: 0.5436 - val_accuracy: 0.8277
# Epoch 15/15
#  - ETA: 4s - loss: 0.2334 - accuracy: 0.9135
