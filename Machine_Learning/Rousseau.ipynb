# %% [markdown]
# # Projet Voltaire 2.0 : Rousseau
# ### Equipe 242
#
#
# **Etape 1** : import des librairies

# %%
import pandas as pd
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten,Dropout,Conv2D
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding

# %% [markdown]
# **Etape 2** : conversion des datasets (.csv) en dataframes pandas et retrait des valeurs aberrantes

# %%
df = pd.read_csv('../Dataset/Data/moyenne.csv')
df = df.dropna()
df
# Out:
#                                                  answer  is_true
# 0     HBOHBSTLHBPQHBMHBGDMaOBGDMBEBMBCCPBCGBSBTMeOBCBPM        0
# 1     HBOHBSTLHBPQHBMHBGDMaOBGDMBEBMBCCPBCGBSBTMeOBC...        0
# 2     HBOHBSTLHBPQHBMHBGDMaOBGDMBEBMBCCPBCGBSBTMeOBC...        1
# 3      HBOHBSTLHBPQHBGDMaOHBGDMBEBMBCCPQBGBCBSBTMReBCBR        0
# 4     HBOHBSTLHBPQHBGDMaOHBGDMBEBMBCCPQBGBCBSBTMReBCBMR        1
# ...                                                 ...      ...
# 2034  HBOHNBLHBPQHBMHBMaOBGDMBEBMBCCPQBCGNOBCBPMReBCBMR        1
# 2035  HBOHNBLHBPQHBGDMHBMaOBGDMBEBMBCCPQBCGNOBCBPMRe...        1
# 2036  HBOHNBLHBPQHBGDLBGDMaOHBGDMBEBMBCCPQBCGNOBCBPM...        1
# 2037  HBOHNBLHBPQHBGDLBGDMaOHBGDMBEBMBCCPQBCGNOBCBPM...        1
# 2038  HBOHNBLHBPQHBGDLBGDMaOHBGDMBEBMBCCPQBCGNOBCBPM...        1
#
# [1842 rows x 2 columns]

# %% [markdown]
# **Etape 3** : Tokeniser les lexemes, et vectorisation des reponses

# %%
tok = Tokenizer(char_level=True)
tok.fit_on_texts(df.answer)
ma = max([len(i) for i in df["answer"]])
ma
X = tok.texts_to_sequences(df["answer"])
X = sequence.pad_sequences(X, maxlen=ma)

# %% [markdown]
# **Etape 4** : Creation modele

# %%
model = Sequential()
model.add(Embedding(len(tok.word_index)+1, 8, input_length=ma))
model.add(Conv1D(filters=16, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 265, 8)            176
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 265, 16)           272
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 265, 16)           0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4240)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                135712
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 136,193
# Trainable params: 136,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Etape 5 : Entrainement Modele

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df["is_true"], test_size=0.4)
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=15, batch_size=1)
# Out:
# Epoch 1/15
# 1105/1105 [==============================] - 4s 3ms/step - loss: 0.6050 - accuracy: 0.6498 - val_loss: 0.5318 - val_accuracy: 0.7286
# Epoch 2/15
# 1105/1105 [==============================] - 3s 2ms/step - loss: 0.5100 - accuracy: 0.7647 - val_loss: 0.5042 - val_accuracy: 0.7381
# Epoch 3/15
#  - ETA: 2s - loss: 0.4886 - accuracy: 0.7804
# Epoch 4/15
# 1105/1105 [==============================] - 5s 5ms/step - loss: 0.4197 - accuracy: 0.8199 - val_loss: 0.4526 - val_accuracy: 0.7978
# Epoch 5/15
# 1105/1105 [==============================] - 5s 4ms/step - loss: 0.3951 - accuracy: 0.8326 - val_loss: 0.4497 - val_accuracy: 0.8019
# Epoch 6/15
# 1105/1105 [==============================] - 5s 5ms/step - loss: 0.3634 - accuracy: 0.8443 - val_loss: 0.4263 - val_accuracy: 0.8155
# Epoch 7/15
#  - ETA: 2s - loss: 0.3169 - accuracy: 0.8605
# Epoch 8/15
# 1105/1105 [==============================] - 5s 5ms/step - loss: 0.3268 - accuracy: 0.8606 - val_loss: 0.4420 - val_accuracy: 0.8182
# Epoch 9/15
# 1105/1105 [==============================] - 6s 5ms/step - loss: 0.3250 - accuracy: 0.8561 - val_loss: 0.4505 - val_accuracy: 0.8195
# Epoch 10/15
# 1105/1105 [==============================] - 6s 6ms/step - loss: 0.2860 - accuracy: 0.8851 - val_loss: 0.4545 - val_accuracy: 0.8195
# Epoch 11/15
#  - ETA: 1s - loss: 0.2913 - accuracy: 0.8880
# Epoch 12/15
# 1105/1105 [==============================] - 7s 6ms/step - loss: 0.2835 - accuracy: 0.8851 - val_loss: 0.4646 - val_accuracy: 0.8236
# Epoch 13/15
#  - ETA: 1s - loss: 0.2719 - accuracy: 0.8790
# Epoch 14/15
# 1105/1105 [==============================] - 10s 9ms/step - loss: 0.2343 - accuracy: 0.8968 - val_loss: 0.4731 - val_accuracy: 0.8223
# Epoch 15/15
# 1105/1105 [==============================] - 12s 11ms/step - loss: 0.2447 - accuracy: 0.8959 - val_loss: 0.4983 - val_accuracy: 0.8385

# %% [markdown]
# **Etape 2** : conversion des datasets (.csv) en dataframes pandas et retrait des valeurs aberrantes

# %%
df = pd.read_csv('moyenne.csv')
df = df.dropna()
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-1c58996ce3d8> in <module>
# ----> 1 df = pd.read_csv('moyenne.csv')
#       2 df = df.dropna()
#       3 df
#       4
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# /usr/local/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'moyenne.csv'

# %% [markdown]
# **Etape 3** : Tokeniser les lexemes, et vectorisation des reponses

# %%
tok = Tokenizer(char_level=True)
tok.fit_on_texts(df.answer)
ma = max([len(i) for i in df["answer"]])
ma
X = tok.texts_to_sequences(df["answer"])
X = sequence.pad_sequences(X, maxlen=ma)

# %% [markdown]
# **Etape 4** : Creation modele

# %%
model = Sequential()
model.add(Embedding(len(tok.word_index)+1, 8, input_length=ma))
model.add(Conv1D(filters=16, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# %% [markdown]
# Etape 5 : Entrainement Modele

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df["is_true"], test_size=0.4)
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=15, batch_size=1)
